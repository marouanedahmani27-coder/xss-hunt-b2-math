# %% [markdown]
# # nb
# [mdlink](javascript:alert(document.domain))
# <img src=x onerror=alert('md-html')>

# %%
print('x')
# Out:
# <img src=x onerror="alert('html-output-'+document.domain)">
# <script>alert('script-output')</script>
# <svg onload="alert('svg-output')"></svg>
# <a href="javascript:alert('a-output')">click</a>
# <iframe src="javascript:alert('iframe-output')"></iframe>
